# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
os.chdir("C:/Users/karthi/Desktop/data analytics/")

# %%
def geo_mean(iterable):
    print(iterable)
    a = np.array(iterable)
    return a.prod()**(1.0/len(a))

# %%
data = pd.read_csv("dataset.csv")

# %%
data.drop(["url","image_url"],axis=1,inplace=True)
data=data.iloc[:1000]

# %%
nRow, nCol = data.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 24 columns

# %%
data.head()
# Out:
#        city  price    year manufacturer             make condition  \
# 0  marshall  11900  2010.0        dodge    challenger se      good
# 1  marshall   1515  1999.0          NaN        fleetwood       NaN
# 2  marshall  17550  2008.0         ford            f-150       NaN
# 3  marshall   2800  2004.0         ford           taurus      good
# 4  marshall    400  2001.0          NaN  2001 Grand Prix       NaN
#
#      cylinders fuel  odometer title_status   ...     type paint_color  \
# 0  6 cylinders  gas   43600.0        clean   ...    coupe         red
# 1          NaN  gas       NaN        clean   ...      NaN         NaN
# 2          NaN  gas       NaN        clean   ...      NaN         NaN
# 3  6 cylinders  gas  168591.0        clean   ...    sedan        grey
# 4          NaN  gas  217000.0        clean   ...      NaN         NaN
#
#        lat      long county_fips county_name  state_fips  state_code  \
# ...

# %%
fig=plt.figure(figsize=(10,15))
ax=fig.gca()
data.hist(ax=ax,bins=20)
plt.show()
# Out:
# C:\Users\karthi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
bx_plt_data=data.head(100)
bx_plt_data.boxplot(column='price')
plt.show()

# %%
data.mean()
# Out:
# price           14565.234000
# year             2004.138000
# odometer       117547.385009
# lat                40.548891
# long              -93.870096
# county_fips     34464.062657
# state_fips         34.384712
# weather            52.132832
# dtype: float64

# %%
import math

def geomean(xs):
    return math.exp(math.fsum(math.log(x) for x in xs) / len(xs))

geomean(data.price)
# Out:
# 6847.059878365745

# %%
data.plot()
# Out:
#             city  price    year   manufacturer                   make  \
# 0       marshall  11900  2010.0          dodge          challenger se
# 1       marshall   1515  1999.0            NaN              fleetwood
# 2       marshall  17550  2008.0           ford                  f-150
# 3       marshall   2800  2004.0           ford                 taurus
# 4       marshall    400  2001.0            NaN        2001 Grand Prix
# 5       marshall   9900  2007.0            gmc                  yukon
# 6       marshall  12500  2015.0           jeep  patriot high altitude
# 7       marshall   3900  2008.0            bmw               3 series
# 8            soo   2700  2018.0            NaN                  Ebike
# 9            soo  12995  2003.0           ford              excursion
# 10           soo   4000  2006.0           chev       express 2500 van
# 11           soo  13000  2002.0      chevrolet                2500 hd
# ...

# %%
data.iloc[:20].plot.box()
plt.show()

# %%
data.iloc[:20].plot.bar()
plt.show()

# %%
freq = {} 
for item in data.year: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1
key=[x for x in freq.keys()]
key
value=[freq[x] for x in freq.keys()]
value
plt.pie(value,labels=key,autopct='%.1f%%',startangle=90)
plt.show()
plt.bar(key,value)
plt.show()

# %%
data.columns
# Out:
# Index(['city', 'price', 'year', 'manufacturer', 'make', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'vin',
#        'drive', 'size', 'type', 'paint_color', 'lat', 'long', 'county_fips',
#        'county_name', 'state_fips', 'state_code', 'state_name', 'weather'],
#       dtype='object')

# %%
for i in data.columns:
    freq={}
    for item in data[i]: 
            if (item in freq): 
                freq[item] += 1
            else: 
                freq[item] = 1
    key=[x for x in freq.keys()]
    value=[freq[x] for x in freq.keys()]
    plt.pie(value,labels=key,autopct='%.1f%%',startangle=90)
    plt.plot()
    plt.show()
